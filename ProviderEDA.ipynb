# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
df = pd.read_csv('Provider_Info.csv', index_col = 'Unnamed: 0' )
# To display the top 5 rows
df.head(5)
# Out:
#   Federal Provider Number                    Provider Name  \
# 0                  365333              BOWLING GREEN MANOR
# 1                  315254  ALARIS HEALTH AT BOULEVARD EAST
# 2                  325071                 AZTEC HEALTHCARE
# 3                  265873                UNION CARE CENTER
# 4                  495309           PELICAN HEALTH NORFOLK
#
#       Provider Address  Provider City Provider State  Provider Zip Code  \
# 0        1021 W POE RD  BOWLING GREEN             OH              43402
# 1  6819 BOULEVARD EAST     GUTTENBERG             NJ               7093
# 2        500 CARE LANE          AZTEC             NM              87410
# 3      1080 MARIE LANE          UNION             MO              63084
# 4   827 NORVIEW AVENUE        NORFOLK             VA              23509
#
#    Provider Phone Number Provider County Name  Number of Certified Beds  \
# 0             4193524694                 Wood                        92
# ...

# %%
df.head()
# Out:
#    Number of Certified Beds  Average Number of Residents Per Day  \
# 0                        92                                 78.0
# 1                       108                                 96.0
# 2                        88                                 75.7
# 3                        60                                 49.9
# 4                        60                                 49.3
#
#    Overall Rating  Health Inspection Rating  QM Rating  Staffing Rating  \
# 0               4                         3          5                3
# 1               5                         5          4                5
# 2               2                         2          4                3
# 3               5                         5          4                3
# 4               2                         2          4                2
#
#    Reported Total Nurse Staffing Hours per Resident per Day  \
# 0                                           3.454720
# ...

# %%
#df = df.drop(['Federal_Provider_Number'], axis=1)

# %% [markdown]
# #Finding Outliers

# %%
col = list(df.columns.values)
print(col)
# Out:
# ['Provider_Name', 'Provider_Address', 'Provider_City', 'Provider_State', 'Provider_Zip_Code', 'Provider_Phone_Number', 'Provider_County_Name', 'Number_of_Certified_Beds', 'Average_Number_of_Residents_Per_Day', 'Provider_Type', 'Overall_Rating', 'Health_Inspection_Rating', 'QM_Rating', 'Staffing_Rating', 'Reported_Total_Nurse_Staffing_Hours_per_Resident_per_Day', 'Reported_Physical_Therapist_Staffing_Hours_per_Resident_Per_Day', 'Total_Weighted_Health_Survey_Score', 'Number_of_Facility_Reported_Incidents', 'Number_of_Substantiated_Complaints', 'Number_of_Fines', 'Total_Number_of_Penalties', 'Avg_Hospital_Stay', 'Treatment_cost', 'Hospital_readmission_rates', 'Patient_wait_time', 'Patient_satisfaction_rate', 'Patient_safety', 'ER_wait_time', 'Primary_Care_ProviderPCP']

# %%
sns.boxplot(x=df['Treatment_cost'])

# %%
sns.boxplot(x=df['Overall_Rating'])

# %%
sns.boxplot(x=df['Health_Inspection_Rating'])

# %%
sns.boxplot(x=df['Patient_safety'])

# %%
sns.boxplot(x='Provider_Type', y="Total_Weighted_Health_Survey_Score", data=df)

# %%
sns.boxplot(x='Primary_Care_ProviderPCP', y="Average_Number_of_Residents_Per_Day", data=df)

# %% [markdown]
# **PLOTTING FEATURES AGAINST EACH OTHER**

# %% [markdown]
# ## **HISTOGRAM**

# %%
df.Provider_State.value_counts().nlargest(40).plot(kind='bar', figsize=(10,5))
plt.title('Number of Providers by State')
plt.ylabel('Number of Providers')
plt.xlabel('State')
# Out:
# Text(0.5, 0, 'State')

# %%
df.Provider_Type.value_counts().plot(kind='bar', figsize=(10,5))
plt.title('Number of Providers by Type')
plt.ylabel('Number of Providers')
plt.xlabel('Type')
# Out:
# Text(0.5, 0, 'Type')

# %%
df.Primary_Care_ProviderPCP.value_counts().plot(kind='bar', figsize=(10,5))
plt.title('Number of Providers by Speciality')
plt.ylabel('Number of Providers')
plt.xlabel('Speciality')
# Out:
# Text(0.5, 0, 'Speciality')

# %%
df.columns
# Out:
# Index(['Federal Provider Number', 'Provider Name', 'Provider Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Provider Phone Number', 'Provider County Name',
#        'Number of Certified Beds', 'Average Number of Residents Per Day',
#        'Provider Type', 'Overall Rating', 'Health Inspection Rating',
#        'QM Rating', 'Staffing Rating',
#        'Reported Total Nurse Staffing Hours per Resident per Day',
#        'Reported Physical Therapist Staffing Hours per Resident Per Day',
#        'Total Weighted Health Survey Score',
#        'Number of Facility Reported Incidents',
#        'Number of Substantiated Complaints', 'Number of Fines',
#        'Total Number of Penalties', 'Avg Hospital Stay',
#        'Treatment cost (in thousands $)', 'Hospital readmission rates(in %)',
#        'Patient wait time (mins)', 'Patient satisfaction rate(out of 10)',
#        'Patient safety(out of 10)', 'ER wait time',
# ...

# %% [markdown]
# ## **HEAT MAP**

# %%
data = df.drop(['Federal Provider Number','Provider City','Provider Zip Code', 'Provider Name', 'Provider Address', 'Provider Phone Number','Provider County Name', 'Patient satisfaction rate(out of 10)'], axis=1)

# %%
corr = data.corr()
ax = sns.heatmap(
    corr, 
    vmin=-1, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    horizontalalignment='right'
);

# %%
sns.clustermap(df.corr(),cmap="BrBG")

# %%
df.head()
# Out:
#    Number of Certified Beds  Average Number of Residents Per Day  \
# 0                        92                                 78.0
# 1                       108                                 96.0
# 2                        88                                 75.7
# 3                        60                                 49.9
# 4                        60                                 49.3
#
#    Overall Rating  Health Inspection Rating  QM Rating  Staffing Rating  \
# 0               4                         3          5                3
# 1               5                         5          4                5
# 2               2                         2          4                3
# 3               5                         5          4                3
# 4               2                         2          4                2
#
#    Reported Total Nurse Staffing Hours per Resident per Day  \
# 0                                           3.454720
# ...

# %%
sns.countplot(df['Overall Rating'])

# %%
sns.distplot(df['Average Number of Residents Per Day'])

# %%
sns.barplot(y='Patient satisfaction rate(out of 10)', x='Primary Care Provider(PCP)', data=df)

# %%
df.columns
# Out:
# Index(['Federal Provider Number', 'Provider Name', 'Provider Address',
#        'Provider City', 'Provider State', 'Provider Zip Code',
#        'Provider Phone Number', 'Provider County Name',
#        'Number of Certified Beds', 'Average Number of Residents Per Day',
#        'Provider Type', 'Overall Rating', 'Health Inspection Rating',
#        'QM Rating', 'Staffing Rating',
#        'Reported Total Nurse Staffing Hours per Resident per Day',
#        'Reported Physical Therapist Staffing Hours per Resident Per Day',
#        'Total Weighted Health Survey Score',
#        'Number of Facility Reported Incidents',
#        'Number of Substantiated Complaints', 'Number of Fines',
#        'Total Number of Penalties', 'Avg Hospital Stay',
#        'Treatment cost (in thousands $)', 'Hospital readmission rates(in %)',
#        'Patient wait time (mins)', 'Patient satisfaction rate(out of 10)',
#        'Patient safety(out of 10)', 'ER wait time',
# ...
